# %% [markdown]
# So this does not work

# %%
# %matplotlib notebook
import numpy as np
import theano.tensor as tt
import pymc3 as pm

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context('notebook')
plt.style.use('seaborn-darkgrid')
print('Running on PyMC3 v{}'.format(pm.__version__))
core_count = 6
# Out:
# Running on PyMC3 v3.8

# %%
def SuperNova_CurveFall(t, A, B, t0, t1, trise, tfall):
    return (A + B*(t1-t0))*np.exp(-(t-t1)/tfall)/(1+np.exp(-(t-t0)/trise))

# %%
#These are the values we are going to use for a test
np.random.seed(212)
trise_A = .3
tfall_A = 2
Amplitude_A = 10.5
Beta_A = -.4
t0_A = 6.7
t1_A = float(15)
size = 50 #data set size
sigma_A = .1 #Telescope error

# %%
time_axis = np.random.uniform(low=t1_A, high=40, size=size)
Y_actual = SuperNova_CurveFall(time_axis, Amplitude_A, Beta_A, t0_A, t1_A, trise_A, tfall_A)
Y_observed = Y_actual + np.random.normal(0,sigma_A,size)

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(10,4))
axes.scatter(time_axis, Y_actual)
axes.set_ylabel('Y')
axes.set_xlabel('X1')
plt.title("Actual Light Curve")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, 'Actual Light Curve')

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(10,4))
axes.errorbar(time_axis, Y_observed, sigma_A, fmt="o")
axes.set_ylabel('Y')
axes.set_xlabel('X1')
plt.title("Error Light Curve")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, 'Error Light Curve')

# %%
basic_model = pm.Model()

# %%
with basic_model:

    # Priors for unknown model parameters
    AboveZeroBound = pm.Bound(pm.Normal, lower = 0.0)
    BelowZeroBound = pm.Bound(pm.Normal, upper = 0.0)
    trise = AboveZeroBound('trise', mu=0, sigma=10)
    tfall = AboveZeroBound('tfall', mu=0, sigma=10)
    Amplitude = AboveZeroBound('Amplitude', mu=0, sigma=10)
    Beta = BelowZeroBound('Beta', mu=0, sigma=10)
    t0 = AboveZeroBound('t0', mu=0, sigma=10)
    t1 = t1_A
    sigma = pm.HalfNormal('sigma', sigma=.2)
    # Expected value of outcome
    mu = SuperNova_CurveFall(time_axis, Amplitude, Beta, t0, t1, trise, tfall)

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal('Y_obs', mu=mu, sigma=sigma, observed=Y_observed)

# %%
map_estimate = pm.find_MAP(model=basic_model)

map_estimate
# Out:
# logp = 33.495, ||grad|| = 5.5719: 100%|██████████████████████████████████████████████| 46/46 [00:00<00:00, 2817.19it/s]
# {'trise_lowerbound__': array(-0.00518809),
#  'tfall_lowerbound__': array(0.71432033),
#  'Amplitude_lowerbound__': array(1.96562594),
#  'Beta_upperbound__': array(-6.13899513),
#  't0_lowerbound__': array(0.47758368),
#  'sigma_log__': array(-2.39338741),
#  'trise': array(0.99482535),
#  'tfall': array(2.04279778),
#  'Amplitude': array(7.13938003),
#  'Beta': array(-0.00215709),
#  't0': array(1.61217417),
#  'sigma': array(0.09131982)}

# %%
with basic_model:
    # 1000 posterior samples
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 4 chains, 18,344 divergences: 100%|█████████████████████████████████| 42000/42000 [05:05<00:00, 137.61draws/s]
# There were 4237 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.3621437905308131, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 5175 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.15183156936336792, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2301 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5475219108005066, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 6631 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.025824096082924602, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
# %matplotlib inline
pm.traceplot(trace)
# Out:
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\ProgramData\Anaconda3\envs\Astronomy\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022833F32988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022833EC1E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022830965EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022833E75148>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022833DCBB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022833DE5E08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022830DEF4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022833CAFF48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022833BD50C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022833B81508>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000228326058C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022833B07388>]],
#       dtype=object)

# %%
trise_R = pm.summary(trace)["mean"]["trise"]
tfall_R = pm.summary(trace)["mean"]["tfall"]
Amplitude_R = pm.summary(trace)["mean"]["Amplitude"]
Beta_R = pm.summary(trace)["mean"]["Beta"]
t0_R = pm.summary(trace)["mean"]["t0"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e426c756879> in <module>
# ----> 1 trise_R = pm.summary(trace)["mean"]["trise"]
#       2 tfall_R = pm.summary(trace)["mean"]["tfall"]
#       3 Amplitude_R = pm.summary(trace)["mean"]["Amplitude"]
#       4 Beta_R = pm.summary(trace)["mean"]["Beta"]
#       5 t0_R = pm.summary(trace)["mean"]["t0"]
#
# NameError: name 'pm' is not defined

# %%
# %matplotlib notebook
fig, ax = plt.subplots()

ax.errorbar(time_axis, Y_observed, .1, fmt='o')
big_time_axis = np.linspace(t1_A,40,num = 100)
ax.plot(big_time_axis, SuperNova_CurveFall(big_time_axis, Amplitude_R, Beta_R, t0_R, t1_A, trise_R, tfall_R))
ax.set_xlabel('x')
ax.set_ylabel('y')
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
