# %%
# %matplotlib inline
import numpy as np
import theano.tensor as tt
import pymc3 as pm
from scipy import stats
from pymc3 import Continuous
from theano import tensor 
from pymc3 import Model, Normal, Slice
from pymc3 import sample
from pymc3 import traceplot
from pymc3.distributions import Interpolated
from theano import as_op
import theano.tensor as tt
import numpy as np
from scipy import stats
import threading
from multiprocessing.pool import ThreadPool
from astropy.table import Table
#exp, log, sqrt

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context('notebook')
plt.style.use('seaborn-darkgrid')
print('Running on PyMC3 v{}'.format(pm.__version__))
core_count = 20
# Out:
# Running on PyMC3 v3.8

# %%
def SuperNova_CurveRise_Scalar(t, A, B, t0, trise, scalar):
    return ((A+B*(t-t0))/(1+np.exp(-(t-t0)/trise)))+scalar
def SuperNova_CurveFall_Scalar(t, A, B, t0, gamma, trise, tfall, scalar):
    return (A + B*((gamma+t0)-t0))*np.exp(-(t-(gamma+t0))/tfall)/(1+np.exp(-(t-t0)/trise))+scalar

# %%
def SuperNova_CurveRise(t, A, B, t0, trise):
    return ((A+B*(t-t0))/(1+np.exp(-(t-t0)/trise)))
def SuperNova_CurveFall(t, A, B, t0, gamma, trise, tfall):
    return (A + B*((gamma+t0)-t0))*np.exp(-(t-(gamma+t0))/tfall)/(1+np.exp(-(t-t0)/trise))

# %%
def from_posteriors(param, samples):
    smins = []
    smaxs = []
    for i in samples:
        smins.append(np.min(i[param]))
        smaxs.append(np.max(i[param]))
    
    smin = np.min(smins)
    smax = np.max(smaxs)
    width = smax - smin

    x = np.linspace(smin, smax, 1000)
    ys = []
    for i in samples:
        ys.append(stats.gaussian_kde(i[param])(x))
    y = np.prod(ys, axis = 0)
    return Interpolated(param, x, y)

# %%
def from_posterior(param, samples):
    smin, smax = np.min(samples[param]), np.max(samples[param])
    width = smax - smin
    x = np.linspace(smin, smax, 1000)
    y = stats.gaussian_kde(samples[param])(x)
    return Interpolated(param, x, y)

# %%
def make_curve(param, samples):
    smins = []
    smaxs = []

    for i in samples:
        smins.append(np.min(i[param]))
        smaxs.append(np.max(i[param]))

    

    smin = np.min(smins)
    smax = np.max(smaxs)
    width = smax - smin

    x, step = np.linspace(smin, smax, 1000, retstep = True)
    ys = []
    for i in samples:
        ys.append(stats.gaussian_kde(i[param])(x))
    y = np.prod(ys, axis = 0)
    y = y + np.exp(-100)
    y_norm = y / (np.sum(y)*step)
    return param, x, y_norm
def make_prior(posterior_param):
    return Interpolated(posterior_param[0],posterior_param[1],posterior_param[2])

# %%
def model_run(model,i,trace, iterations, core):
    with model:
        # 10000 posterior samples
        trace[i] = pm.sample(iterations, cores = core)

# %%
ztf_data = Table.read("flux_obs_19yvq.csv")

# %%
filter_types = np.unique(ztf_data["filt"])[3:6]
filter_number = np.size(filter_types)

# %%
end_A = np.max(ztf_data["t_restframe"])

# %%
#This is the test data we are going to use for a test
time_axis_filters = []
Y_observed_filter = []
Y_unc = []
scale = 1000000
ztf_data = ztf_data[3:-1]
for i in filter_types:
    print(i)
    time_axis_filters.append(np.asarray(ztf_data["t_restframe"][np.where(ztf_data["filt"] == i)]))
    light_data = np.asarray(ztf_data["flux_Jy"][np.where(ztf_data["filt"] == i)])
    Y_observed_filter.append(light_data * scale)
    light_data_unc = np.asarray(ztf_data["flux_unc_Jy"][np.where(ztf_data["filt"] == i)])
    Y_unc.append(light_data_unc * scale)
# Out:
# g
# i
# r

# %%
time_axis_filters = np.asarray(time_axis_filters)
Y_observed_filter = np.asarray(Y_observed_filter)
Y_unc = np.asarray(Y_unc)

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(10,4))
colours = ["green", "indigo", "red"]
for i in range(filter_number):
    #axes.scatter(time_axis_filters[i], Y_observed_filter[i], color = colours[i])
    axes.errorbar(time_axis_filters[i], Y_observed_filter[i], Y_unc[i], fmt = "o", color = colours[i])

axes.set_ylabel('Y')
axes.set_xlabel('X1')
plt.title("Observed Light Curve")
# Out:
# Text(0.5, 1.0, 'Observed Light Curve')

# %%
model_filters = []
for i in range(filter_number):
    model_filters.append(pm.Model())

# %%
for i in range(filter_number):
    with model_filters[i]:

        # Priors for unknown model parameters

        trise = pm.Uniform('trise', lower = 0.01, upper = 50)
        tfall = pm.Uniform('tfall', lower = 1, upper = 300)
        
        Amp_Guess = np.max(Y_observed_filter[i])-np.min(Y_observed_filter[i])
        Amplitude = pm.Normal('Amplitude', mu=Amp_Guess, sigma=Amp_Guess/2)
        
        Beta = pm.Uniform('Beta', lower = -np.max(Y_observed_filter[i])/150, upper = 0)
        
        location_high = time_axis_filters[i][np.argmax(Y_observed_filter[i])]
        t0 = pm.Uniform('t0', lower = 0, upper = location_high)
        
        sigma_est = np.sqrt(np.sum(Y_unc[i]**2))
        sigma = pm.HalfNormal('sigma', sigma=sigma_est)
        
        limits = np.absolute(np.max(Y_observed_filter[i]))
        scalar = pm.Uniform('scalar', lower = -limits, upper = limits)

        #gamma = pm.Uniform('gamma', lower = np.min(time_axis), upper = np.max(time_axis), testval = (least_slope[0]-))
        no_p = pm.Normal.dist(mu = 5, sigma = 5)
        yes_p = pm.Normal.dist(mu = 60, sigma = 30)

        gamma = pm.Mixture("gamma", w=[2/3,1/3], comp_dists = [no_p, yes_p])
        #gamma = pm.math.sum(pm.Normal("no_p", mu = 5, sigma = 5),pm.Normal("yes_p", mu = 60, sigma = 30))

        # Expected value of outcome
        mu_rise = SuperNova_CurveRise_Scalar(time_axis_filters[i], Amplitude, Beta, t0, trise, scalar)
        mu_fall = SuperNova_CurveFall_Scalar(time_axis_filters[i], Amplitude, Beta, t0, gamma, trise, tfall, scalar)

        mu_switch = pm.math.switch(gamma+t0 >= time_axis_filters[i], mu_rise, mu_fall)

        # Likelihood (sampling distribution) of observations
        Y_obs = pm.Normal('Y_obs', mu=mu_switch, sigma=sigma, observed=Y_observed_filter[i])

# %%
trace = []
for basic_model in model_filters:
    with basic_model:
        # 10000 posterior samples
        iterations = int(400000/core_count)
        tune_i = int(iterations/2)
        start = pm.find_MAP(model=basic_model)
        trace.append(pm.sample(iterations, tune = tune_i, cores = core_count, start = start))
# Out:
# logp = -824.4, ||grad|| = 0.090357: 100%|██████████| 164/164 [00:00<00:00, 1281.51it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (20 chains in 20 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 20 chains, 1 divergences: 100%|██████████| 600000/600000 [04:24<00:00, 2272.21draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5756231075106528, but should be close to 0.8. Try to increase the number of tuning steps.
# logp = -613.35, ||grad|| = 4.422: 100%|██████████| 178/178 [00:00<00:00, 1724.91it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (20 chains in 20 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 20 chains, 20,077 divergences: 100%|██████████| 600000/600000 [17:07<00:00, 583.83draws/s]
# There were 259 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6775687180335689, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 9025 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.13799854814134072, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 699 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6350653024712382, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 974 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5966944633622526, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 8627 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.16739676229994782, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.917717417249492, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 477 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6457332392772391, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9461153657007519, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8990989457954011, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8845769522986691, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8906441778788109, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 10% for some parameters.
# logp = -782.42, ||grad|| = 2.9345: 100%|██████████| 110/110 [00:00<00:00, 1296.80it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (20 chains in 20 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 20 chains, 220 divergences: 100%|██████████| 600000/600000 [05:29<00:00, 1821.18draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6922373986870642, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9179356496329207, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8965951363639644, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 209 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5438567014887397, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.675424538544244, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.605785153524267, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
for posterior in trace:
    pm.plot_posterior(posterior)

# %%
summary_tables = []
for i in trace:
    summary_tables.append(pm.summary(i))

# %%
summary_tables[0]
# Out:
#                mean      sd    hpd_3%   hpd_97%  mcse_mean  mcse_sd  ess_mean  \
# Amplitude  4043.998  30.702  3985.561  4101.093      0.073    0.052  176785.0
# gamma        12.787   0.207    12.399    13.176      0.000    0.000  211096.0
# trise         1.786   0.063     1.667     1.905      0.000    0.000  251416.0
# tfall         7.371   0.216     6.966     7.779      0.000    0.000  195538.0
# Beta        -27.591   1.647   -29.259   -24.605      0.004    0.003  200066.0
# t0            9.911   0.071     9.776    10.045      0.000    0.000  264212.0
# sigma        85.601   5.482    75.409    95.907      0.010    0.007  303637.0
# scalar      333.381  15.091   304.958   361.629      0.033    0.023  210013.0
#
#              ess_sd  ess_bulk  ess_tail  r_hat
# Amplitude  176785.0  182250.0  173617.0    1.0
# gamma      211096.0  211170.0  245129.0    1.0
# trise      251416.0  251563.0  240073.0    1.0
# tfall      195348.0  195759.0  227094.0    1.0
# Beta       200066.0  230023.0  196190.0    1.0
# t0         264212.0  264413.0  236221.0    1.0
# sigma      300649.0  306702.0  262396.0    1.0
# scalar     210013.0  210112.0  241067.0    1.0

# %%
trise_R = []
tfall_R = []
Amplitude_R = []
Beta_R = []
t0_R = []
gamma_R = []
scalar_R = []
for i in summary_tables:
    trise_R.append(i["mean"]["trise"])
    tfall_R.append(i["mean"]["tfall"])
    Amplitude_R.append(i["mean"]["Amplitude"])
    Beta_R.append(i["mean"]["Beta"])
    t0_R.append(i["mean"]["t0"])
    gamma_R.append(i["mean"]["gamma"])
    scalar_R.append(i["mean"]["scalar"])

# %%
fig, ax = plt.subplots(figsize=(10,4))
colours = ["green", "indigo", "red"]

for i in range(filter_number):
    big_time_axis_rise = np.linspace(0,t0_R[i]+gamma_R[i],num = 100)
    ax.plot(big_time_axis_rise, SuperNova_CurveRise_Scalar(big_time_axis_rise, Amplitude_R[i], Beta_R[i], t0_R[i], trise_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    big_time_axis_fall = np.linspace(t0_R[i]+gamma_R[i],end_A,num = 100)
    ax.plot(big_time_axis_fall, SuperNova_CurveFall_Scalar(big_time_axis_fall, Amplitude_R[i], Beta_R[i], t0_R[i], gamma_R[i], trise_R[i], tfall_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    ax.errorbar(time_axis_filters[i], Y_observed_filter[i], Y_unc[i], fmt = "o", color = colours[i])
    
ax.set_xlabel('x')
ax.set_ylabel('y_observed')
# Out:
# Text(0, 0.5, 'y_observed')

# %%
combined_model = []
for i in range(filter_number):
    combined_model.append(pm.Model())

# %%
trise_posterior = make_curve("trise", trace)

tfall_posterior = make_curve("tfall", trace)

Beta_posterior = make_curve("Beta", trace)

t0_posterior = make_curve("t0", trace)

sigma_posterior = make_curve("sigma", trace)

gamma_posterior = make_curve("gamma", trace)

# %%
for i in range(filter_number):
    with combined_model[i]:
        Amp_Guess = np.max(Y_observed_filter[i])-np.min(Y_observed_filter[i])
        Amplitude = pm.Normal('Amplitude', mu=Amp_Guess, sigma=Amp_Guess/2)

        trise = make_prior(trise_posterior)

        tfall = make_prior(tfall_posterior)

        Beta = make_prior(Beta_posterior)

        t0 = make_prior(t0_posterior)

        sigma = make_prior(sigma_posterior)

        gamma = make_prior(gamma_posterior)
        
        scalar = from_posterior("scalar", trace[i])

        # Expected value of outcome
        mu_rise = SuperNova_CurveRise_Scalar(time_axis_filters[i], Amplitude, Beta, t0, trise, scalar)
        mu_fall = SuperNova_CurveFall_Scalar(time_axis_filters[i], Amplitude, Beta, t0, gamma, trise, tfall, scalar)

        mu_switch = pm.math.switch(gamma+t0 >= time_axis_filters[i], mu_rise, mu_fall)

        # Likelihood (sampling distribution) of observations
        Y_obs = pm.Normal('Y_obs', mu=mu_switch, sigma=sigma, observed=Y_observed_filter[i])

# %%
trace_all = []
for basic_model in combined_model:
    with basic_model:
        # 10000 posterior samples
        iterations = int(400000/core_count)
        tune_i = int(iterations/2)
        start = pm.find_MAP(model=basic_model)
        trace_all.append(pm.sample(iterations, tune = tune_i, cores = core_count, start = start))
# Out:
# logp = -823.33, ||grad|| = 2.9944: 100%|██████████| 47/47 [00:00<00:00, 1103.99it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (20 chains in 20 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, tfall, trise, Amplitude]
# Sampling 20 chains, 1 divergences: 100%|██████████| 600000/600000 [04:24<00:00, 2268.16draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# logp = -1,061.7, ||grad|| = 24.395: 100%|██████████| 39/39 [00:00<00:00, 892.95it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (20 chains in 20 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, tfall, trise, Amplitude]
# Sampling 20 chains, 0 divergences:   0%|          | 0/600000 [00:00<?, ?draws/s]/home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16998')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16993')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16999')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16995')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16985')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16990')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16984')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16983')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16989')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16986')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16997')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16991')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16996' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16999')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16993')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16985')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16995')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16984')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16989')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16986')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16997')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16988')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16991')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16998' (I am process '17000')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16993')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16985')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16995')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16989')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16984')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16983')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16986')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16988')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16997')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16991')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16999' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16985')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16995')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16984')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16989')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16986')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16991')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16997')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '17000')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16993' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16995')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16989')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16986')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '17000')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16984')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16983')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16991')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16997')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '16988')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16985' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16984')
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16986')
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16994')
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16989')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16991')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16983')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16997')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16995' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16989')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16991')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16984')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16997')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16994')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16986' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16991')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16984')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16997')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16989' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16991')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16997')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16994')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '17000')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16988')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16984' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16991')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16990')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16988')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16997' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16994')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '17000')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '16990')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '16988')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16991' (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '17000')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16994' (I am process '16990')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16994' (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16994' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16994' (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16994' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16994' (I am process '16983')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17000' (I am process '16983')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17000' (I am process '16990')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17000' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17000' (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17000' (I am process '16982')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17000' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16990')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16983' (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16983' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16983' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16983' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16990' (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16990' (I am process '16982')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16990' (I am process '16987')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16990' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '16987')
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '17001')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16982' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by unknown process (I am process '17001')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '16987' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# INFO (theano.gof.compilelock): Waiting for existing lock by process '17001' (I am process '16988')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/xjh0560/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-redhat-7.5-Maipo-x86_64-3.6.10-64/lock_dir
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# Sampling 20 chains, 0 divergences:   0%|          | 0/600000 [02:27<?, ?draws/s]
# Bad initial energy, check any log probabilities that are inf or -inf, nan or very small:
# Series([], )
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/parallel_sampling.py", line 160, in _start_loop
#     point, stats = self._compute_point()
#   File "/home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/parallel_sampling.py", line 191, in _compute_point
#     point, stats = self._step_method.step(self._point)
#   File "/home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/step_methods/arraystep.py", line 247, in step
#     apoint, stats = self.astep(array)
#   File "/home/xjh0560/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/step_methods/hmc/base_hmc.py", line 144, in astep
#     raise SamplingError("Bad initial energy")
# pymc3.exceptions.SamplingError: Bad initial energy
# """
#
# The above exception was the direct cause of the following exception:
#
# SamplingError                             Traceback (most recent call last)
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/parallel_sampling.py in _start_loop()
#     159                 try:
# --> 160                     point, stats = self._compute_point()
#     161                 except SamplingError as e:
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/parallel_sampling.py in _compute_point()
#     190         if self._step_method.generates_stats:
# --> 191             point, stats = self._step_method.step(self._point)
#     192         else:
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/step_methods/arraystep.py in step()
#     246         if self.generates_stats:
# --> 247             apoint, stats = self.astep(array)
#     248             point = self._logp_dlogp_func.array_to_full_dict(apoint)
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/step_methods/hmc/base_hmc.py in astep()
#     143             self._warnings.append(warning)
# --> 144             raise SamplingError("Bad initial energy")
#     145
#
# SamplingError: Bad initial energy
#
# The above exception was the direct cause of the following exception:
#
# ParallelSamplingError                     Traceback (most recent call last)
# <ipython-input-21-aa294e2dedfb> in <module>
#       6         tune_i = int(iterations/2)
#       7         start = pm.find_MAP(model=basic_model)
# ----> 8         trace_all.append(pm.sample(iterations, tune = tune_i, cores = core_count, start = start))
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, **kwargs)
#     467         _print_step_hierarchy(step)
#     468         try:
# --> 469             trace = _mp_sample(**sample_args)
#     470         except pickle.PickleError:
#     471             _log.warning("Could not pickle model, sampling singlethreaded.")
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, **kwargs)
#    1057         try:
#    1058             with sampler:
# -> 1059                 for draw in sampler:
#    1060                     trace = traces[draw.chain - chain]
#    1061                     if trace.supports_sampler_stats and draw.stats is not None:
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/parallel_sampling.py in __iter__(self)
#     392
#     393         while self._active:
# --> 394             draw = ProcessAdapter.recv_draw(self._active)
#     395             proc, is_last, draw, tuning, stats, warns = draw
#     396             if self._progress is not None:
#
# ~/.conda/envs/pymc3_env/lib/python3.6/site-packages/pymc3/parallel_sampling.py in recv_draw(processes, timeout)
#     295             else:
#     296                 error = RuntimeError("Chain %s failed." % proc.chain)
# --> 297             raise error from old_error
#     298         elif msg[0] == "writing_done":
#     299             proc._readable = True
#
# ParallelSamplingError: Bad initial energy

# %%
for i in trace_all:
    pm.traceplot(i)

# %%
summary_tables = []
for i in trace_all:
    summary_tables.append(pm.summary(i))

# %%
trise_R = []
tfall_R = []
Amplitude_R = []
Beta_R = []
t0_R = []
gamma_R = []
scalar_R = []
for i in summary_tables:
    trise_R.append(i["mean"]["trise"])
    tfall_R.append(i["mean"]["tfall"])
    Amplitude_R.append(i["mean"]["Amplitude"])
    Beta_R.append(i["mean"]["Beta"])
    t0_R.append(i["mean"]["t0"])
    gamma_R.append(i["mean"]["gamma"])
    scalar_R.append(i["mean"]["scalar"])

# %%
print(trise_R)
print(tfall_R)
print(Amplitude_R)
print(Beta_R)
print(t0_R)
print(gamma_R)
print(scalar_R)

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10,4))
colours = ["green", "indigo", "red"]

for i in range(filter_number):
    big_time_axis_rise = np.linspace(0,t0_R[i]+gamma_R[i],num = 100)
    ax.plot(big_time_axis_rise, SuperNova_CurveRise_Scalar(big_time_axis_rise, Amplitude_R[i], Beta_R[i], t0_R[i], trise_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    big_time_axis_fall = np.linspace(t0_R[i]+gamma_R[i],end_A,num = 100)
    ax.plot(big_time_axis_fall, SuperNova_CurveFall_Scalar(big_time_axis_fall, Amplitude_R[i], Beta_R[i], t0_R[i], gamma_R[i], trise_R[i], tfall_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    ax.errorbar(time_axis_filters[i], Y_observed_filter[i], Y_unc[i], fmt = "o", color = colours[i])
    
ax.set_xlabel('x')
ax.set_ylabel('y_observed')
