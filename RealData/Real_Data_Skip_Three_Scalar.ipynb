# %%
# %matplotlib inline
import numpy as np
import theano.tensor as tt
import pymc3 as pm
from scipy import stats
from pymc3 import Continuous
from theano import tensor 
from pymc3 import Model, Normal, Slice
from pymc3 import sample
from pymc3 import traceplot
from pymc3.distributions import Interpolated
from theano import as_op
import theano.tensor as tt
import numpy as np
from scipy import stats
import threading
from multiprocessing.pool import ThreadPool
from astropy.table import Table
#exp, log, sqrt

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context('notebook')
plt.style.use('seaborn-darkgrid')
print('Running on PyMC3 v{}'.format(pm.__version__))
core_count = 32
# Out:
# Running on PyMC3 v3.8

# %%
def SuperNova_CurveRise_Scalar(t, A, B, t0, trise, scalar):
    return ((A+B*(t-t0))/(1+np.exp(-(t-t0)/trise)))+scalar
def SuperNova_CurveFall_Scalar(t, A, B, t0, gamma, trise, tfall, scalar):
    return (A + B*((gamma+t0)-t0))*np.exp(-(t-(gamma+t0))/tfall)/(1+np.exp(-(t-t0)/trise))+scalar

# %%
def SuperNova_CurveRise(t, A, B, t0, trise):
    return ((A+B*(t-t0))/(1+np.exp(-(t-t0)/trise)))
def SuperNova_CurveFall(t, A, B, t0, gamma, trise, tfall):
    return (A + B*((gamma+t0)-t0))*np.exp(-(t-(gamma+t0))/tfall)/(1+np.exp(-(t-t0)/trise))

# %%
def from_posteriors(param, samples):
    smins = []
    smaxs = []
    for i in samples:
        smins.append(np.min(i[param]))
        smaxs.append(np.max(i[param]))
    
    smin = np.min(smins)
    smax = np.max(smaxs)
    width = smax - smin

    x = np.linspace(smin, smax, 1000)
    ys = []
    for i in samples:
        ys.append(stats.gaussian_kde(i[param])(x))
    y = np.prod(ys, axis = 0)
    return Interpolated(param, x, y)

# %%
def from_posterior(param, samples):
    smin, smax = np.min(samples[param]), np.max(samples[param])
    width = smax - smin
    x = np.linspace(smin, smax, 1000)
    y = stats.gaussian_kde(samples[param])(x)
    return Interpolated(param, x, y)

# %%
def make_curve(param, samples):
    smins = []
    smaxs = []

    for i in samples:
        smins.append(np.min(i[param]))
        smaxs.append(np.max(i[param]))

    

    smin = np.min(smins)
    smax = np.max(smaxs)
    width = smax - smin

    x, step = np.linspace(smin, smax, 1000, retstep = True)
    ys = []
    for i in samples:
        ys.append(stats.gaussian_kde(i[param])(x))
    y = np.prod(ys, axis = 0)
    y = y + np.exp(-100)
    y_norm = y / (np.sum(y)*step)
    return param, x, y_norm
def make_prior(posterior_param):
    return Interpolated(posterior_param[0],posterior_param[1],posterior_param[2])

# %%
def model_run(model,i,trace, iterations, core):
    with model:
        # 10000 posterior samples
        trace[i] = pm.sample(iterations, cores = core)

# %%
ztf_data = Table.read("flux_obs_19yvq.csv")

# %%
filter_types = np.unique(ztf_data["filt"])[3:6]
filter_number = np.size(filter_types)

# %%
end_A = np.max(ztf_data["t_restframe"])

# %%
#This is the test data we are going to use for a test
time_axis_filters = []
Y_observed_filter = []
Y_unc = []
scale = 10 ** (-1 * np.log10(np.min(ztf_data["flux_Jy"])))
ztf_data = ztf_data[3:-1]
for i in filter_types:
    print(i)
    time_axis_filters.append(np.asarray(ztf_data["t_restframe"][np.where(ztf_data["filt"] == i)]))
    light_data = np.asarray(ztf_data["flux_Jy"][np.where(ztf_data["filt"] == i)])
    Y_observed_filter.append(light_data * scale)
    light_data_unc = np.asarray(ztf_data["flux_unc_Jy"][np.where(ztf_data["filt"] == i)])
    Y_unc.append(light_data_unc * scale)
# Out:
# g
# i
# r

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(10,4))
colours = ["green", "indigo", "red"]
for i in range(filter_number):
    #axes.scatter(time_axis_filters[i], Y_observed_filter[i], color = colours[i])
    axes.errorbar(time_axis_filters[i], Y_observed_filter[i], Y_unc[i], fmt = "o", color = colours[i])

axes.set_ylabel('Y')
axes.set_xlabel('X1')
plt.title("Observed Light Curve")
# Out:
# Text(0.5, 1.0, 'Observed Light Curve')

# %%
model_filters = []
for i in range(filter_number):
    model_filters.append(pm.Model())

# %%
for i in range(filter_number):
    with model_filters[i]:

        # Priors for unknown model parameters

        trise = pm.Uniform('trise', lower = 0.01, upper = 50)
        tfall = pm.Uniform('tfall', lower = 1, upper = 300)
        Amp_Guess = np.max(Y_observed_filter[i])-np.min(Y_observed_filter[i])
        Amplitude = pm.Normal('Amplitude', mu=Amp_Guess, sigma=Amp_Guess/2)
        Beta = pm.Uniform('Beta', lower = -np.max(Y_observed_filter[i])/150, upper = 0)
        t0 = pm.Uniform('t0', lower = np.min(time_axis_filters[i]), upper = np.max(time_axis_filters[i]))
        sigma_est = np.sqrt(np.sum(Y_unc[i]**2))
        sigma = pm.HalfNormal('sigma', sigma=sigma_est)
        scalar = pm.Uniform('scalar', lower = 0, upper = np.max(Y_observed_filter[i]))

        #gamma = pm.Uniform('gamma', lower = np.min(time_axis), upper = np.max(time_axis), testval = (least_slope[0]-))
        no_p = pm.Normal.dist(mu = 5, sigma = 5)
        yes_p = pm.Normal.dist(mu = 60, sigma = 30)

        gamma = pm.Mixture("gamma", w=[2/3,1/3], comp_dists = [no_p, yes_p])
        #gamma = pm.math.sum(pm.Normal("no_p", mu = 5, sigma = 5),pm.Normal("yes_p", mu = 60, sigma = 30))

        # Expected value of outcome
        mu_rise = SuperNova_CurveRise_Scalar(time_axis_filters[i], Amplitude, Beta, t0, trise, scalar)
        mu_fall = SuperNova_CurveFall_Scalar(time_axis_filters[i], Amplitude, Beta, t0, gamma, trise, tfall, scalar)

        mu_switch = pm.math.switch(gamma+t0 >= time_axis_filters[i], mu_rise, mu_fall)

        # Likelihood (sampling distribution) of observations
        Y_obs = pm.Normal('Y_obs', mu=mu_switch, sigma=sigma, observed=Y_observed_filter[i])

# %%
map_estimate = []
for basic_model in model_filters:
    map_estimate.append(pm.find_MAP(model=basic_model))
# Out:
# logp = -901.09, ||grad|| = 0.095367: 100%|██████████| 41/41 [00:00<00:00, 1530.36it/s]
# logp = -382.37, ||grad|| = 41.161: 100%|██████████| 179/179 [00:00<00:00, 1669.21it/s]
# logp = -699.99, ||grad|| = 0.21742: 100%|██████████| 95/95 [00:00<00:00, 1580.28it/s]

# %%
trace = []
for basic_model in model_filters:
    with basic_model:
        # 10000 posterior samples
        iterations = int(100000/core_count)
        trace.append(pm.sample(iterations, cores = core_count))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (32 chains in 32 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 32 chains, 0 divergences: 100%|██████████| 116000/116000 [01:35<00:00, 1219.91draws/s]
# The acceptance probability does not match the target. It is 0.8857682586361061, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8863501249756562, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.890703350031135, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8924309360184256, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8843949263505252, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8886665569384858, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8881581842357673, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8948916974233152, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.879006412337371, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8852495348091464, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8806666299441008, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8868720302341299, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8815221252810357, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8827584270111833, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8861544475679958, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8874278614606186, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8943104025938479, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8957576558302962, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9095461514664611, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8931792916520471, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8858389391942814, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8958090184006354, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8846376878006877, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9103327271116353, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8954376098500673, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9035264918657994, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9029816831928743, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8979416213457696, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (32 chains in 32 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 32 chains, 3,586 divergences: 100%|██████████| 116000/116000 [02:42<00:00, 715.82draws/s]
# There were 2146 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.04803384835582953, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9194591301809739, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8886721207013967, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.901536887540874, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9011637996838895, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 1412 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.1538030669454597, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9331601966110173, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9043312707011679, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9433934799667596, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9182818634300743, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9338314683304025, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9006056788009738, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8856792220081716, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8958858284723663, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9392705482429314, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9218524984101545, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9373196419119495, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8892224207478738, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9143318943581882, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9068628289819688, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9360047231169382, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9047114092494898, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9019262352804376, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (32 chains in 32 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 32 chains, 0 divergences: 100%|██████████| 116000/116000 [02:01<00:00, 956.81draws/s]
# The acceptance probability does not match the target. It is 0.8804543474743616, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8851077985281048, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9059712506901405, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8894413971292029, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8861991922508342, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9045225046203329, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.882736655214474, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8909939831317862, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.901082736703639, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8942734606921684, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8796700365962755, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8805434954583636, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8964406017404714, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8934906051492811, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8841076060606009, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8824847159917585, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9056284506271637, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8843787697310296, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9048254638120474, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
for posterior in trace:
    pm.plot_posterior(posterior)

# %%
smin1, smax1 = np.min(trace[0]["t0"]), np.max(trace[0]["t0"])
smin2, smax2 = np.min(trace[1]["t0"]), np.max(trace[1]["t0"])
smin3, smax3 = np.min(trace[2]["t0"]), np.max(trace[2]["t0"])
smin = np.min([smin1,smin2,smin3])
smax = np.max([smax1,smax2,smax3])
width = smax - smin

x = np.linspace(smin, smax, 1000)
y1 = stats.gaussian_kde(trace[0]["t0"])(x)
y2 = stats.gaussian_kde(trace[1]["t0"])(x)
y3 = stats.gaussian_kde(trace[2]["t0"])(x)
#plt.plot(x, y1)
#plt.plot(x, y2)
#plt.plot(x, y3)
plt.plot(x, y1*y2*y3)

# %%
combined_model = []
for i in range(filter_number):
    combined_model.append(pm.Model())

# %%
#time_axis = np.hstack(time_axis_filters)
#Y_observed = np.hstack(Y_observed_filter)
#Y_actual = np.hstack(Y_actual_filter)
'''
trise = from_posterior("trise", trace)

tfall = from_posterior("tfall", trace)

Amplitude = from_posterior("Amplitude", trace)

Beta = from_posterior("Beta", trace)

t0 = from_posterior("t0", trace)

sigma = from_posterior("sigma", trace)

gamma = from_posterior("gamma", trace)
'''
# Out:
# '\ntrise = from_posterior("trise", trace)\n\ntfall = from_posterior("tfall", trace)\n\nAmplitude = from_posterior("Amplitude", trace)\n\nBeta = from_posterior("Beta", trace)\n\nt0 = from_posterior("t0", trace)\n\nsigma = from_posterior("sigma", trace)\n\ngamma = from_posterior("gamma", trace)\n'

# %%
name, x, y = make_curve("t0", trace)

# %%
plt.plot(x,y)
plt.yscale("log")

# %%
trise_posterior = make_curve("trise", trace)

tfall_posterior = make_curve("tfall", trace)

Amplitude_posterior = make_curve("Amplitude", trace)

Beta_posterior = make_curve("Beta", trace)

t0_posterior = make_curve("t0", trace)

sigma_posterior = make_curve("sigma", trace)

gamma_posterior = make_curve("gamma", trace)

# %%
for i in range(filter_number):
    with combined_model[i]:
        trise = make_prior(trise_posterior)

        tfall = make_prior(tfall_posterior)

        Amplitude = make_prior(Amplitude_posterior)

        Beta = make_prior(Beta_posterior)

        t0 = make_prior(t0_posterior)

        sigma = make_prior(sigma_posterior)

        gamma = make_prior(gamma_posterior)
        
        scalar = from_posterior("scalar", trace[i])

        # Expected value of outcome
        mu_rise = SuperNova_CurveRise_Scalar(time_axis_filters[i], Amplitude, Beta, t0, trise, scalar)
        mu_fall = SuperNova_CurveFall_Scalar(time_axis_filters[i], Amplitude, Beta, t0, gamma, trise, tfall, scalar)

        mu_switch = pm.math.switch(gamma+t0 >= time_axis_filters[i], mu_rise, mu_fall)

        # Likelihood (sampling distribution) of observations
        Y_obs = pm.Normal('Y_obs', mu=mu_switch, sigma=sigma, observed=Y_observed_filter[i])

# %%
combined_map_estimate = []
for i in combined_model:
    combined_map_estimate.append(pm.find_MAP(model=i))
# Out:
# logp = -579.92, ||grad|| = 21.793: 100%|██████████| 57/57 [00:00<00:00, 918.02it/s]
# logp = -445.84, ||grad|| = 1.9065: 100%|██████████| 107/107 [00:00<00:00, 939.96it/s]
# logp = -431.49, ||grad|| = 9.2716: 100%|██████████| 80/80 [00:00<00:00, 938.40it/s]

# %%
trace_all = []
for basic_model in combined_model:
    with basic_model:
        # 10000 posterior samples
        iterations = int(100000/core_count)
        trace_all.append(pm.sample(iterations, cores = core_count))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (32 chains in 32 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 32 chains, 3 divergences: 100%|██████████| 116000/116000 [03:18<00:00, 584.97draws/s]
# The acceptance probability does not match the target. It is 0.4788722086995932, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.4773231747072099, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (32 chains in 32 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 32 chains, 448 divergences: 100%|██████████| 116000/116000 [02:08<00:00, 904.06draws/s]
# There were 30 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.669390734858205, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 117 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.4349530224638283, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 56 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.35412801480345507, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9363038982681974, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8884625286682628, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 243 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.27600200507141637, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.2 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (32 chains in 32 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 32 chains, 0 divergences: 100%|██████████| 116000/116000 [01:40<00:00, 1149.35draws/s]

# %%
for i in trace_all:
    pm.traceplot(i)

# %%
summary_tables = []
for i in trace_all:
    summary_tables.append(pm.summary(i))

# %%
trise_R = []
tfall_R = []
Amplitude_R = []
Beta_R = []
t0_R = []
gamma_R = []
scalar_R = []
for i in summary_tables:
    trise_R.append(i["mean"]["trise"])
    tfall_R.append(i["mean"]["tfall"])
    Amplitude_R.append(i["mean"]["Amplitude"]/scale)
    Beta_R.append(i["mean"]["Beta"]/scale)
    t0_R.append(i["mean"]["t0"])
    gamma_R.append(i["mean"]["gamma"])
    scalar_R.append(i["mean"]["scalar"]/scale)

# %%
print(trise_R)
print(tfall_R)
print(Amplitude_R)
print(Beta_R)
print(t0_R)
print(gamma_R)
print(scalar_R)
# Out:
# [2.084, 2.289, 2.201]
# [8.344, 33.013, 18.035]
# [0.004094461659158957, 0.0035435436494596303, 0.004644449753732814]
# [-1.6409599836042132e-05, -1.870036636463958e-05, -1.8484898225811109e-06]
# [9.867, 9.714, 9.796]
# [11.59, 11.63, 12.445]
# [0.0002910180725587513, 1.678383397190211e-05, 0.0004297455326792098]

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10,4))
colours = ["green", "indigo", "red"]

for i in range(filter_number):
    big_time_axis_rise = np.linspace(0,t0_R[i]+gamma_R[i],num = 100)
    ax.plot(big_time_axis_rise, SuperNova_CurveRise_Scalar(big_time_axis_rise, Amplitude_R[i], Beta_R[i], t0_R[i], trise_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    big_time_axis_fall = np.linspace(t0_R[i]+gamma_R[i],end_A,num = 100)
    ax.plot(big_time_axis_fall, SuperNova_CurveFall_Scalar(big_time_axis_fall, Amplitude_R[i], Beta_R[i], t0_R[i], gamma_R[i], trise_R[i], tfall_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    ax.errorbar(time_axis_filters[i], Y_observed_filter[i]/scale, Y_unc[i]/scale, fmt = "o", color = colours[i])
    
ax.set_xlabel('x')
ax.set_ylabel('y_observed')
# Out:
# Text(0, 0.5, 'y_observed')
