# %%
# %matplotlib inline
import numpy as np
import theano.tensor as tt
import pymc3 as pm
from scipy import stats
from pymc3 import Continuous
from theano import tensor 
from pymc3 import Model, Normal, Slice
from pymc3 import sample
from pymc3 import traceplot
from pymc3.distributions import Interpolated
from theano import as_op
import theano.tensor as tt
import numpy as np
from scipy import stats
import threading
from multiprocessing.pool import ThreadPool
from astropy.table import Table
#exp, log, sqrt

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context('notebook')
plt.style.use('seaborn-darkgrid')
print('Running on PyMC3 v{}'.format(pm.__version__))
core_count = 32
# Out:
# Running on PyMC3 v3.8

# %%
def SuperNova_CurveRise(t, A, B, t0, trise, scalar):
    return ((A+B*(t-t0))/(1+np.exp(-(t-t0)/trise)))+scalar
def SuperNova_CurveFall(t, A, B, t0, gamma, trise, tfall, scalar):
    return (A + B*((gamma+t0)-t0))*np.exp(-(t-(gamma+t0))/tfall)/(1+np.exp(-(t-t0)/trise))+scalar

# %%
def SuperNova_CurveRise(t, A, B, t0, trise):
    return ((A+B*(t-t0))/(1+np.exp(-(t-t0)/trise)))
def SuperNova_CurveFall(t, A, B, t0, gamma, trise, tfall):
    return (A + B*((gamma+t0)-t0))*np.exp(-(t-(gamma+t0))/tfall)/(1+np.exp(-(t-t0)/trise))

# %%
def from_posteriors(param, samples):
    smins = []
    smaxs = []
    for i in samples:
        smins.append(np.min(i[param]))
        smaxs.append(np.max(i[param]))
    
    smin = np.min(smins)
    smax = np.max(smaxs)
    width = smax - smin

    x = np.linspace(smin, smax, 1000)
    ys = []
    for i in samples:
        ys.append(stats.gaussian_kde(i[param])(x))
    y = np.prod(ys, axis = 0)
    return Interpolated(param, x, y)

# %%
def from_posterior(param, samples):
    smin, smax = np.min(samples[param]), np.max(samples[param])
    width = smax - smin
    x = np.linspace(smin, smax, 1000)
    y = stats.gaussian_kde(samples[param])(x)
    return Interpolated(param, x, y)

# %%
def make_curve(param, samples):
    smins = []
    smaxs = []

    for i in samples:
        smins.append(np.min(i[param]))
        smaxs.append(np.max(i[param]))

    

    smin = np.min(smins)
    smax = np.max(smaxs)
    width = smax - smin

    x, step = np.linspace(smin, smax, 1000, retstep = True)
    ys = []
    for i in samples:
        ys.append(stats.gaussian_kde(i[param])(x))
    y = np.prod(ys, axis = 0)
    y = y + np.exp(-100)
    y_norm = y / (np.sum(y)*step)
    return param, x, y_norm
def make_prior(posterior_param):
    return Interpolated(posterior_param[0],posterior_param[1],posterior_param[2])

# %%
def model_run(model,i,trace, iterations, core):
    with model:
        # 10000 posterior samples
        trace[i] = pm.sample(iterations, cores = core)

# %%
ztf_data = Table.read("flux_obs_19yvq.csv")

# %%
filter_types = np.unique(ztf_data["filt"])[3:6]
filter_number = np.size(filter_types)

# %%
end_A = np.max(ztf_data["t_restframe"])

# %%
#This is the test data we are going to use for a test
time_axis_filters = []
Y_observed_filter = []
Y_unc = []
scale = 10 ** (-1 * np.log10(np.min(ztf_data["flux_Jy"])))
for i in filter_types:
    print(i)
    time_axis_filters.append(np.asarray(ztf_data["t_restframe"][np.where(ztf_data["filt"] == i)]))
    light_data = np.asarray(ztf_data["flux_Jy"][np.where(ztf_data["filt"] == i)])
    Y_observed_filter.append(light_data * scale)
    light_data_unc = np.asarray(ztf_data["flux_unc_Jy"][np.where(ztf_data["filt"] == i)])
    Y_unc.append(light_data_unc * scale)
# Out:
# g
# i
# r

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(10,4))
colours = ["green", "indigo", "red"]
for i in range(filter_number):
    #axes.scatter(time_axis_filters[i], Y_observed_filter[i], color = colours[i])
    axes.errorbar(time_axis_filters[i], Y_observed_filter[i], Y_unc[i], fmt = "o", color = colours[i])

axes.set_ylabel('Y')
axes.set_xlabel('X1')
plt.title("Observed Light Curve")
# Out:
# Text(0.5, 1.0, 'Observed Light Curve')

# %%
model_filters = []
for i in range(filter_number):
    model_filters.append(pm.Model())

# %%
for i in range(filter_number):
    with model_filters[i]:

        # Priors for unknown model parameters

        trise = pm.Uniform('trise', lower = 0.01, upper = 50)
        tfall = pm.Uniform('tfall', lower = 1, upper = 300)
        Amp_Guess = np.max(Y_observed_filter[i])-np.min(Y_observed_filter[i])
        Amplitude = pm.Normal('Amplitude', mu=Amp_Guess, sigma=Amp_Guess/2)
        Beta = pm.Uniform('Beta', lower = -np.max(Y_observed_filter[i])/150, upper = 0)
        t0 = pm.Uniform('t0', lower = np.min(time_axis_filters[i]), upper = np.max(time_axis_filters[i]))
        sigma_est = np.sqrt(np.sum(Y_unc[i]**2))
        sigma = pm.HalfNormal('sigma', sigma=sigma_est)
        scalar = pm.Uniform('scalar', lower = 0, upper = np.max(Y_observed_filter[i]))

        #gamma = pm.Uniform('gamma', lower = np.min(time_axis), upper = np.max(time_axis), testval = (least_slope[0]-))
        no_p = pm.Normal.dist(mu = 5, sigma = 5)
        yes_p = pm.Normal.dist(mu = 60, sigma = 30)

        gamma = pm.Mixture("gamma", w=[2/3,1/3], comp_dists = [no_p, yes_p])
        #gamma = pm.math.sum(pm.Normal("no_p", mu = 5, sigma = 5),pm.Normal("yes_p", mu = 60, sigma = 30))

        # Expected value of outcome
        mu_rise = SuperNova_CurveRise(time_axis_filters[i], Amplitude, Beta, t0, trise, scalar)
        mu_fall = SuperNova_CurveFall(time_axis_filters[i], Amplitude, Beta, t0, gamma, trise, tfall, scalar)

        mu_switch = pm.math.switch(gamma+t0 >= time_axis_filters[i], mu_rise, mu_fall)

        # Likelihood (sampling distribution) of observations
        Y_obs = pm.Normal('Y_obs', mu=mu_switch, sigma=sigma, observed=Y_observed_filter[i])

# %%
map_estimate = []
for basic_model in model_filters:
    map_estimate.append(pm.find_MAP(model=basic_model))
# Out:
# logp = -914.3, ||grad|| = 0.71181: 100%|██████████| 28/28 [00:00<00:00, 1391.82it/s]
# logp = -407.36, ||grad|| = 0.15264: 100%|██████████| 164/164 [00:00<00:00, 1573.25it/s]
# logp = -462.53, ||grad|| = 0.3097: 100%|██████████| 226/226 [00:00<00:00, 1602.89it/s]

# %%
trace = []
for basic_model in model_filters:
    with basic_model:
        # 10000 posterior samples
        iterations = int(100000/core_count)
        trace.append(pm.sample(iterations, cores = core_count))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (24 chains in 24 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 24 chains, 0 divergences: 100%|██████████| 111984/111984 [01:32<00:00, 1212.78draws/s]
# The acceptance probability does not match the target. It is 0.8796809212619077, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8885503215255734, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8911706695413508, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8883162985657924, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9077726990302377, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8838295124741332, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8947811399966933, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9024629182074637, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9538375993449186, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8963372173253513, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8977832211756608, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.892544539223698, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8936862269776308, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.896085256985223, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8815792997308581, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8854360355848281, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8916491982269905, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (24 chains in 24 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 24 chains, 5,101 divergences: 100%|██████████| 111984/111984 [03:09<00:00, 591.65draws/s]
# The acceptance probability does not match the target. It is 0.9298686661852942, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9428832823327924, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9402119688179719, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9029046218881593, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.950021917752334, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.896841716908375, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9080748743160106, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9056494476082099, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8916711379879971, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 71 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6930422973189138, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9128548048753764, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9227015365279893, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2870 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.05124332619230858, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9025506501190711, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.89912899068186, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8887685850011151, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2156 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.11176146258895577, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9308721960448089, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.92175206902691, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (24 chains in 24 jobs)
# NUTS: [gamma, scalar, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 24 chains, 0 divergences: 100%|██████████| 111984/111984 [01:52<00:00, 991.18draws/s]
# The acceptance probability does not match the target. It is 0.8998461849729668, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8971542222842159, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8955790595057376, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8921779732106794, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8990853363305554, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8818765413248937, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.897598356185738, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
for posterior in trace:
    pm.plot_posterior(posterior)

# %%
smin1, smax1 = np.min(trace[0]["t0"]), np.max(trace[0]["t0"])
smin2, smax2 = np.min(trace[1]["t0"]), np.max(trace[1]["t0"])
smin3, smax3 = np.min(trace[2]["t0"]), np.max(trace[2]["t0"])
smin = np.min([smin1,smin2,smin3])
smax = np.max([smax1,smax2,smax3])
width = smax - smin

x = np.linspace(smin, smax, 1000)
y1 = stats.gaussian_kde(trace[0]["t0"])(x)
y2 = stats.gaussian_kde(trace[1]["t0"])(x)
y3 = stats.gaussian_kde(trace[2]["t0"])(x)
#plt.plot(x, y1)
#plt.plot(x, y2)
#plt.plot(x, y3)
plt.plot(x, y1*y2*y3)

# %%
combined_model = []
for i in range(filter_number):
    combined_model.append(pm.Model())

# %%
#time_axis = np.hstack(time_axis_filters)
#Y_observed = np.hstack(Y_observed_filter)
#Y_actual = np.hstack(Y_actual_filter)
'''
trise = from_posterior("trise", trace)

tfall = from_posterior("tfall", trace)

Amplitude = from_posterior("Amplitude", trace)

Beta = from_posterior("Beta", trace)

t0 = from_posterior("t0", trace)

sigma = from_posterior("sigma", trace)

gamma = from_posterior("gamma", trace)
'''
# Out:
# '\ntrise = from_posterior("trise", trace)\n\ntfall = from_posterior("tfall", trace)\n\nAmplitude = from_posterior("Amplitude", trace)\n\nBeta = from_posterior("Beta", trace)\n\nt0 = from_posterior("t0", trace)\n\nsigma = from_posterior("sigma", trace)\n\ngamma = from_posterior("gamma", trace)\n'

# %%
name, x, y = make_curve("t0", trace)

# %%
plt.plot(x,y)
plt.yscale("log")

# %%
trise_posterior = make_curve("trise", trace)

tfall_posterior = make_curve("tfall", trace)

Amplitude_posterior = make_curve("Amplitude", trace)

Beta_posterior = make_curve("Beta", trace)

t0_posterior = make_curve("t0", trace)

sigma_posterior = make_curve("sigma", trace)

gamma_posterior = make_curve("gamma", trace)

# %%
for i in range(filter_number):
    with combined_model[i]:
        trise = make_prior(trise_posterior)

        tfall = make_prior(tfall_posterior)

        Amplitude = make_prior(Amplitude_posterior)

        Beta = make_prior(Beta_posterior)

        t0 = make_prior(t0_posterior)

        sigma = make_prior(sigma_posterior)

        gamma = make_prior(gamma_posterior)
        
        scalar = from_posterior("scalar", trace[i])

        # Expected value of outcome
        mu_rise = SuperNova_CurveRise(time_axis_filters[i], Amplitude, Beta, t0, trise, scalar)
        mu_fall = SuperNova_CurveFall(time_axis_filters[i], Amplitude, Beta, t0, gamma, trise, tfall, scalar)

        mu_switch = pm.math.switch(gamma+t0 >= time_axis_filters[i], mu_rise, mu_fall)

        # Likelihood (sampling distribution) of observations
        Y_obs = pm.Normal('Y_obs', mu=mu_switch, sigma=sigma, observed=Y_observed_filter[i])

# %%
combined_map_estimate = []
for i in combined_model:
    combined_map_estimate.append(pm.find_MAP(model=i))
# Out:
# logp = -587.44, ||grad|| = 0.078156: 100%|██████████| 82/82 [00:00<00:00, 915.90it/s]
# logp = -454.52, ||grad|| = 0.10298: 100%|██████████| 122/122 [00:00<00:00, 937.19it/s]
# logp = -439.7, ||grad|| = 0.020013: 100%|██████████| 62/62 [00:00<00:00, 913.65it/s]

# %%
trace_all = []
for basic_model in combined_model:
    with basic_model:
        # 10000 posterior samples
        iterations = int(100000/core_count)
        trace_all.append(pm.sample(iterations, cores = core_count))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (24 chains in 24 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 24 chains, 169 divergences: 100%|██████████| 111984/111984 [04:11<00:00, 444.58draws/s]
# There were 166 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.32761713040606494, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.477623521398386, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9527745744091631, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (24 chains in 24 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 24 chains, 447 divergences: 100%|██████████| 111984/111984 [02:20<00:00, 796.22draws/s]
# The acceptance probability does not match the target. It is 0.8802193633507843, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 443 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.4360590182030472, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (24 chains in 24 jobs)
# NUTS: [scalar, gamma, sigma, t0, Beta, Amplitude, tfall, trise]
# Sampling 24 chains, 0 divergences: 100%|██████████| 111984/111984 [01:26<00:00, 1294.00draws/s]
# The acceptance probability does not match the target. It is 0.8878644613176607, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8790517495304463, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
for i in trace_all:
    pm.traceplot(i)

# %%
summary_tables = []
for i in trace_all:
    summary_tables.append(pm.summary(i))

# %%
trise_R = []
tfall_R = []
Amplitude_R = []
Beta_R = []
t0_R = []
gamma_R = []
scalar_R = []
for i in summary_tables:
    trise_R.append(i["mean"]["trise"])
    tfall_R.append(i["mean"]["tfall"])
    Amplitude_R.append(i["mean"]["Amplitude"]/scale)
    Beta_R.append(i["mean"]["Beta"]/scale)
    t0_R.append(i["mean"]["t0"])
    gamma_R.append(i["mean"]["gamma"])
    scalar_R.append(i["mean"]["scalar"]/scale)

# %%
print(trise_R)
print(tfall_R)
print(Amplitude_R)
print(Beta_R)
print(t0_R)
print(gamma_R)
print(scalar_R)
# Out:
# [2.097, 2.328, 2.175]
# [8.048, 32.896, 17.736]
# [0.004092272956485595, 0.003555916056799728, 0.004587033164949206]
# [-1.8745728078077155e-05, -1.8473557797451716e-05, -1.1907449777362983e-06]
# [9.909, 9.733, 9.808]
# [11.84, 11.215, 12.531]
# [0.00030627094870213533, 3.0948028992784365e-05, 0.00046183894493629285]

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10,4))
colours = ["green", "indigo", "red"]

for i in range(filter_number):
    big_time_axis_rise = np.linspace(0,t0_R[i]+gamma_R[i],num = 100)
    ax.plot(big_time_axis_rise, SuperNova_CurveRise(big_time_axis_rise, Amplitude_R[i], Beta_R[i], t0_R[i], trise_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    big_time_axis_fall = np.linspace(t0_R[i]+gamma_R[i],end_A,num = 100)
    ax.plot(big_time_axis_fall, SuperNova_CurveFall(big_time_axis_fall, Amplitude_R[i], Beta_R[i], t0_R[i], gamma_R[i], trise_R[i], tfall_R[i], scalar_R[i]), color = colours[i])

for i in range(filter_number):
    ax.errorbar(time_axis_filters[i], Y_observed_filter[i]/scale, Y_unc[i]/scale, fmt = "o", color = colours[i])
    
ax.set_xlabel('x')
ax.set_ylabel('y_observed')
# Out:
# Text(0, 0.5, 'y_observed')
